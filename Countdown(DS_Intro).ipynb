# %%
import time
import datetime
print("Merhaba Geleceğin VERİ BİLİMCİLERİ!!!\n(Geri Sayımdan çıkmak için 'Interrupt')\n")
try: 
    def countdown(stop):
        while True:
            difference = stop - datetime.datetime.now()
            count_hours, rem = divmod(difference.seconds, 3600)
            count_minutes, count_seconds = divmod(rem, 60)
            print('DATA SCIENCE Introya '
                  + str(difference.days) + " gün "
                  + str(count_hours) + " saat "
                  + str(count_minutes) + " dakika "
                  + str(count_seconds) + " saniye kaldı "
                  )
            time.sleep(1)
    end_time = datetime.datetime(2021, 12, 17, 21, 30, 0)
    countdown(end_time)
    
except KeyboardInterrupt:
    print('\n17 Aralık Cuma 21.30 (TR) de görüşmek üzere...')
# Out:
# Merhaba Geleceğin VERİ BİLİMCİLERİ!!!
# (Geri Sayımdan çıkmak için 'Interrupt')
#
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 58 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 57 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 56 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 55 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 54 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 53 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 52 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 51 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 50 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 49 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 48 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 47 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 46 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 45 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 44 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 43 saniye kaldı
# DATA SCIENCE Introya 1 gün 11 saat 41 dakika 42 saniye kaldı
#
# 17 Aralık Cuma 21.30 (TR) de görüşmek üzere...
